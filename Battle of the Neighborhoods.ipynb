# %% [markdown]
# **Import the necessary libraries.**

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation


# !pip install geopy
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize


! pip install folium==0.5.0
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Requirement already satisfied: geopy in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (2.0.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geopy) (1.50)
# Requirement already satisfied: folium==0.5.0 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (0.5.0)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.25.0)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (1.15.0)
# Requirement already satisfied: branca in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (0.4.1)
# Requirement already satisfied: jinja2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from folium==0.5.0) (2.11.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (3.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (1.26.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->folium==0.5.0) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from jinja2->folium==0.5.0) (1.1.1)
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'Z00J24USHWMMPGSJQJWZE2RTBW51JKGD1KJQCQYKLHWKYWSD' # your Foursquare ID
CLIENT_SECRET = 'GHGLXZNPKPXGX1OABROQSABZN3DGAJLIKUN0O5DYRWCUULVY' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: Z00J24USHWMMPGSJQJWZE2RTBW51JKGD1KJQCQYKLHWKYWSD
# CLIENT_SECRET:GHGLXZNPKPXGX1OABROQSABZN3DGAJLIKUN0O5DYRWCUULVY

# %% [markdown]
# **Find the nearest Italian restaurants to the new apartment building.**

# %%
search_query = 'Italian'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Italian .... OK!

# %%
address = '215 East 24th St, New York, NY'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 40.7393046 -73.98172600106602

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=Z00J24USHWMMPGSJQJWZE2RTBW51JKGD1KJQCQYKLHWKYWSD&client_secret=GHGLXZNPKPXGX1OABROQSABZN3DGAJLIKUN0O5DYRWCUULVY&ll=40.7393046,-73.98172600106602&v=20180604&query=Italian&radius=500&limit=30'

# %%
results = requests.get(url).json()

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                                name  \
# 0  4b6c4ebaf964a520612f2ce3  Olive Tree Italian
# 1  5c81b0dca6ec980039fd0da5  Ralph's Famous Italian Ices
# 2  57f54dcccd10dbbdcf2f6f62  Lena's Italian Kitchen
# 3  50356a65e4b045e72e72263f  Italian Danish Food Mafia
# 4  57263c65498ea26fae449c38  Nic & Dora's Italian Sandwich Shop
#
#                                                                                                                                                                                                                                        categories  \
# 0  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 1  [{'id': '4bf58dd8d48988d1c9941735', 'name': 'Ice Cream Shop', 'pluralName': 'Ice Cream Shops', 'shortName': 'Ice Cream', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_', 'suffix': '.png'}, 'primary': True}]
# 2  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 3  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
# 4  [{'id': '4bf58dd8d48988d110941735', 'name': 'Italian Restaurant', 'pluralName': 'Italian Restaurants', 'shortName': 'Italian', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_', 'suffix': '.png'}, 'primary': True}]
#
#      referralId  hasPerk   location.address location.crossStreet  \
# 0  v-1607816704  False    182 Lexington Ave  btw 31st & 32nd
# 1  v-1607816704  False    370 2nd Ave        btwn 21st & 22nd st
# 2  v-1607816704  False    551 2nd Ave        30th & 31st St
# 3  v-1607816704  False    NaN                NaN
# 4  v-1607816704  False    124 E 27th St      Lexington Ave.
#
#    location.lat  location.lng  \
# 0  40.744736    -73.981216
# 1  40.736937    -73.981615
# 2  40.742576    -73.977564
# 3  40.744689    -73.979539
# 4  40.742099    -73.983575
#
#                                                                                                                     location.labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 40.74473571777344, 'lng': -73.98121643066406}]
# 1  [{'label': 'display', 'lat': 40.73693700923917, 'lng': -73.98161454804094}]
# 2  [{'label': 'display', 'lat': 40.742575976794534, 'lng': -73.97756432712956}, {'label': 'entrance', 'lat': 40.742611, 'lng': -73.977665}]
# 3  [{'label': 'display', 'lat': 40.74468888054811, 'lng': -73.97953932869252}]
# 4  [{'label': 'display', 'lat': 40.742098999999996, 'lng': -73.983575}, {'label': 'entrance', 'lat': 40.742182, 'lng': -73.983513}]
#
#    ...  location.state location.country  \
# 0  ...  NY              United States
# 1  ...  NY              United States
# 2  ...  NY              United States
# 3  ...  NY              United States
# 4  ...  NY              United States
#
#                                                   location.formattedAddress  \
# 0  [182 Lexington Ave (btw 31st & 32nd), New York, NY 10016, United States]
# 1  [370 2nd Ave (btwn 21st & 22nd st), New York, NY 10010, United States]
# 2  [551 2nd Ave (30th & 31st St), New York, NY 10016, United States]
# 3  [New York, NY 10016, United States]
# 4  [124 E 27th St (Lexington Ave.), New York, NY 10016, United States]
#
#   delivery.id  \
# 0  NaN
# 1  NaN
# 2  347492
# 3  NaN
# 4  NaN
#
#                                                                                                                                                                                        delivery.url  \
# 0  NaN
# 1  NaN
# 2  https://www.seamless.com/menu/lenas-italian-kitchen-551-2nd-ave-new-york/347492?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=347492
# 3  NaN
# 4  NaN
#
#   delivery.provider.name             delivery.provider.icon.prefix  \
# 0  NaN                    NaN
# 1  NaN                    NaN
# 2  seamless               https://fastly.4sqi.net/img/general/cap/
# 3  NaN                    NaN
# 4  NaN                    NaN
#
#   delivery.provider.icon.sizes               delivery.provider.icon.name  \
# 0  NaN                          NaN
# 1  NaN                          NaN
# 2  [40, 50]                     /delivery_provider_seamless_20180129.png
# 3  NaN                          NaN
# 4  NaN                          NaN
#
#   venuePage.id
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
# [5 rows x 24 columns]

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                  name          categories            address  \
# 0  Olive Tree Italian                  Italian Restaurant  182 Lexington Ave
# 1  Ralph's Famous Italian Ices         Ice Cream Shop      370 2nd Ave
# 2  Lena's Italian Kitchen              Italian Restaurant  551 2nd Ave
# 3  Italian Danish Food Mafia           Italian Restaurant  NaN
# 4  Nic & Dora's Italian Sandwich Shop  Italian Restaurant  124 E 27th St
# 5  Vino Fine Wine & Spirits            Wine Shop           121 E 27th St
# 6  Frank's Trattoria                   Pizza Place         371 1st Ave
#
#                crossStreet        lat        lng  \
# 0  btw 31st & 32nd          40.744736 -73.981216
# 1  btwn 21st & 22nd st      40.736937 -73.981615
# 2  30th & 31st St           40.742576 -73.977564
# 3  NaN                      40.744689 -73.979539
# 4  Lexington Ave.           40.742099 -73.983575
# 5  btw Park & Lex Avenues   40.742358 -73.983710
# 6  btwn E 21st & E 22nd St  40.736031 -73.979160
#
#                                                                                                                              labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 40.74473571777344, 'lng': -73.98121643066406}]
# 1  [{'label': 'display', 'lat': 40.73693700923917, 'lng': -73.98161454804094}]
# 2  [{'label': 'display', 'lat': 40.742575976794534, 'lng': -73.97756432712956}, {'label': 'entrance', 'lat': 40.742611, 'lng': -73.977665}]
# 3  [{'label': 'display', 'lat': 40.74468888054811, 'lng': -73.97953932869252}]
# 4  [{'label': 'display', 'lat': 40.742098999999996, 'lng': -73.983575}, {'label': 'entrance', 'lat': 40.742182, 'lng': -73.983513}]
# 5  [{'label': 'display', 'lat': 40.74235793600694, 'lng': -73.98370965459888}]
# 6  [{'label': 'display', 'lat': 40.7360311287152, 'lng': -73.97915989751004}, {'label': 'entrance', 'lat': 40.736077, 'lng': -73.97933}]
#
#    distance postalCode  cc      city state        country  \
# 0  606       10016      US  New York  NY    United States
# 1  263       10010      US  New York  NY    United States
# 2  505       10016      US  New York  NY    United States
# 3  627       10016      US  New York  NY    United States
# 4  347       10016      US  New York  NY    United States
# 5  378       10016      US  New York  NY    United States
# 6  423       10010      US  New York  NY    United States
#
#                                                               formattedAddress  \
# 0  [182 Lexington Ave (btw 31st & 32nd), New York, NY 10016, United States]
# 1  [370 2nd Ave (btwn 21st & 22nd st), New York, NY 10010, United States]
# 2  [551 2nd Ave (30th & 31st St), New York, NY 10016, United States]
# 3  [New York, NY 10016, United States]
# 4  [124 E 27th St (Lexington Ave.), New York, NY 10016, United States]
# 5  [121 E 27th St (btw Park & Lex Avenues), New York, NY 10016, United States]
# 6  [371 1st Ave (btwn E 21st & E 22nd St), New York, NY 10010, United States]
#
#                          id
# 0  4b6c4ebaf964a520612f2ce3
# 1  5c81b0dca6ec980039fd0da5
# 2  57f54dcccd10dbbdcf2f6f62
# 3  50356a65e4b045e72e72263f
# 4  57263c65498ea26fae449c38
# 5  4a843b7df964a520f9fb1fe3
# 6  4b4bca62f964a520cba726e3

# %%
dataframe_filtered.name
# Out:
# 0    Olive Tree Italian
# 1    Ralph's Famous Italian Ices
# 2    Lena's Italian Kitchen
# 3    Italian Danish Food Mafia
# 4    Nic & Dora's Italian Sandwich Shop
# 5    Vino Fine Wine & Spirits
# 6    Frank's Trattoria
# Name: name, dtype: object

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# **Explore other popular places in your new neighborhood.**

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=Z00J24USHWMMPGSJQJWZE2RTBW51JKGD1KJQCQYKLHWKYWSD&client_secret=GHGLXZNPKPXGX1OABROQSABZN3DGAJLIKUN0O5DYRWCUULVY&ll=40.7393046,-73.98172600106602&v=20180604&radius=500&limit=30'

# %%
import requests

# %%
results = requests.get(url).json()
'There are {} around your neighborhood.'.format(len(results['response']['groups'][0]['items']))
# Out:
# 'There are 30 around your neighborhood.'

# %%
items = results['response']['groups'][0]['items']
items[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '5b6dfaf610b30300243dd960',
#   'name': 'Craft + Carry',
#   'location': {'address': '284 3rd Ave',
#    'crossStreet': '22nd and 23rd St',
#    'lat': 40.738359625993866,
#    'lng': -73.98359951193653,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.738359625993866,
#      'lng': -73.98359951193653},
#     {'label': 'entrance', 'lat': 40.738391, 'lng': -73.98367}],
#    'distance': 189,
#    'postalCode': '10010',
#    'cc': 'US',
#    'city': 'New York',
#    'state': 'NY',
#    'country': 'United States',
#    'formattedAddress': ['284 3rd Ave (22nd and 23rd St)',
#     'New York, NY 10010',
#     'United States']},
#   'categories': [{'id': '56aa371ce4b08b9a8d57356c',
#     'name': 'Beer Bar',
#     'pluralName': 'Beer Bars',
#     'shortName': 'Beer Bar',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-5b6dfaf610b30300243dd960-0'}

# %%
dataframe = json_normalize(items) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in dataframe.columns if col.startswith('venue.location.')] + ['venue.id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# filter the category for each row
dataframe_filtered['venue.categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean columns
dataframe_filtered.columns = [col.split('.')[-1] for col in dataframe_filtered.columns]

dataframe_filtered.head(10)
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """Entry point for launching an IPython kernel.
#                                              name           categories  \
# 0  Craft + Carry                                   Beer Bar
# 1  Lamazou                                         Sandwich Place
# 2  Reflections Center for Conscious Living & Yoga  Yoga Studio
# 3  Street Taco                                     Taco Place
# 4  Freehand New York                               Hotel
# 5  Simon & The Whale                               American Restaurant
# 6  Gramercy Park Optical                           Optical Shop
# 7  Think Coffee                                    Coffee Shop
# 8  Malt & Mold                                     Gourmet Shop
# 9  Molly's Shebeen                                 Irish Pub
#
#             address             crossStreet        lat        lng  \
# 0  284 3rd Ave       22nd and 23rd St        40.738360 -73.983600
# 1  370 3rd Ave       at E 27th St            40.741225 -73.981427
# 2  227 E 24th St     2nd & 3rd Aves.         40.739050 -73.981487
# 3  358 3rd Avenue    at 26th St              40.740859 -73.981836
# 4  23 Lexington Ave  NaN                     40.739740 -73.984622
# 5  23 Lexington Ave  E 23rd St               40.739662 -73.984450
# 6  344 3rd Ave       btwn E 25th & 26th St.  40.740421 -73.982369
# 7  280 3rd Ave       E 22nd St.              40.738156 -73.983742
# 8  362 2nd Ave       btwn 21st & 22nd St     40.736677 -73.981472
# 9  287 3rd Ave       btwn E 22nd & 23rd St.  40.738365 -73.983513
#
#                                                                                                                             labeledLatLngs  \
# 0  [{'label': 'display', 'lat': 40.738359625993866, 'lng': -73.98359951193653}, {'label': 'entrance', 'lat': 40.738391, 'lng': -73.98367}]
# 1  [{'label': 'display', 'lat': 40.74122491291197, 'lng': -73.98142749590318}]
# 2  [{'label': 'display', 'lat': 40.73905027871491, 'lng': -73.98148705717242}, {'label': 'entrance', 'lat': 40.739046, 'lng': -73.98137}]
# 3  [{'label': 'display', 'lat': 40.74085938226586, 'lng': -73.98183554234694}]
# 4  [{'label': 'display', 'lat': 40.73974003939308, 'lng': -73.9846218065663}]
# 5  [{'label': 'display', 'lat': 40.739662, 'lng': -73.98445}]
# 6  [{'label': 'display', 'lat': 40.740421413112166, 'lng': -73.9823685132501}, {'label': 'entrance', 'lat': 40.740408, 'lng': -73.982202}]
# 7  [{'label': 'display', 'lat': 40.738156312933405, 'lng': -73.98374210961263}, {'label': 'entrance', 'lat': 40.73808, 'lng': -73.983902}]
# 8  [{'label': 'display', 'lat': 40.736677, 'lng': -73.981472}]
# 9  [{'label': 'display', 'lat': 40.738364660508275, 'lng': -73.9835132890077}, {'label': 'entrance', 'lat': 40.738296, 'lng': -73.983333}]
#
#    distance postalCode  cc      city state        country  \
# 0  189       10010      US  New York  NY    United States
# 1  215       10016      US  New York  NY    United States
# 2  34        10010      US  New York  NY    United States
# 3  173       10016      US  New York  NY    United States
# 4  249       10010      US  New York  NY    United States
# 5  233       10010      US  New York  NY    United States
# 6  135       10010      US  New York  NY    United States
# 7  212       10010      US  New York  NY    United States
# 8  293       10010      US  New York  NY    United States
# 9  183       10010      US  New York  NY    United States
#
#                                                             formattedAddress  \
# 0  [284 3rd Ave (22nd and 23rd St), New York, NY 10010, United States]
# 1  [370 3rd Ave (at E 27th St), New York, NY 10016, United States]
# 2  [227 E 24th St (2nd & 3rd Aves.), New York, NY 10010, United States]
# 3  [358 3rd Avenue (at 26th St), New York, NY 10016, United States]
# 4  [23 Lexington Ave, New York, NY 10010, United States]
# 5  [23 Lexington Ave (E 23rd St), New York, NY 10010, United States]
# 6  [344 3rd Ave (btwn E 25th & 26th St.), New York, NY 10010, United States]
# 7  [280 3rd Ave (E 22nd St.), New York, NY 10010, United States]
# 8  [362 2nd Ave (btwn 21st & 22nd St), New York, NY 10010, United States]
# 9  [287 3rd Ave (btwn E 22nd & 23rd St.), New York, NY 10010, United States]
#
#     neighborhood                        id
# 0  NaN            5b6dfaf610b30300243dd960
# 1  NaN            49cc3fd3f964a52058591fe3
# 2  NaN            4b67625ef964a520a54b2be3
# 3  Rose Hill      58defd40d25ded1a4f7efa4b
# 4  NaN            59d4126b8194fc768a2cfcde
# 5  Rose Hill      5a5ec2e4bb8d3614bb5d49f5
# 6  NaN            4af49de4f964a52061f421e3
# 7  NaN            580226bb38fae0dde3f6bd9a
# 8  Gramercy Park  545fd218498e729596469903
# 9  NaN            4197f180f964a5201f1e1fe3

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Apartment',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'
